# %%
df_posts = (
    spark.read
    .format("xml")
    .option("rowTag","row")
    .load("/Volumes/my_workspace/default/star-schema/Posts.xml")
)

bronze_posts = df_posts
bronze_posts.write.mode("overwrite").saveAsTable("bronze_posts_raw")

# %%
df_Badges = (
    spark.read
    .format("xml")
    .option("rowTag","row")
    .load("/Volumes/my_workspace/default/star-schema/Badges.xml")
)

bronze_Badges = df_Badges
bronze_Badges.write.mode("overwrite").saveAsTable("bronze_Badges_raw")

# %%
df_comments = (
    spark.read
    .format("xml")
    .option("rowTag","row")
    .load("/Volumes/my_workspace/default/star-schema/Comments.xml")
)

bronze_comments = df_comments
bronze_comments.write.mode("overwrite").saveAsTable("bronze_comments_raw")

# %%
df_posthistory = (
    spark.read
    .format("xml")
    .option("rowTag","row")
    .load("/Volumes/my_workspace/default/star-schema/PostHistory.xml")
)

bronze_posthistory = df_posthistory
bronze_posthistory.write.mode("overwrite").saveAsTable("bronze_posthistory_raw")

# %%
df_postlink = (
    spark.read
    .format("xml")
    .option("rowTag","row")
    .load("/Volumes/my_workspace/default/star-schema/PostLinks.xml")
)

bronze_postlink = df_postlink
bronze_postlink.write.mode("overwrite").saveAsTable("bronze_postlink_raw")

# %%
df_tags = (
    spark.read
    .format("xml")
    .option("rowTag","row")
    .load("/Volumes/my_workspace/default/star-schema/Tags.xml")
)

bronze_tags = df_tags
bronze_tags.write.mode("overwrite").saveAsTable("bronze_tags_raw")

# %%
df_users = (
    spark.read
    .format("xml")
    .option("rowTag","row")
    .load("/Volumes/my_workspace/default/star-schema/Users.xml")
)

bronze_users = df_users
bronze_users.write.mode("overwrite").saveAsTable("bronze_users_raw")

# %%
df_votes = (
    spark.read
    .format("xml")
    .option("rowTag","row")
    .load("/Volumes/my_workspace/default/star-schema/Votes.xml")
)

bronze_votes = df_votes
bronze_votes.write.mode("overwrite").saveAsTable("bronze_votes_raw")
